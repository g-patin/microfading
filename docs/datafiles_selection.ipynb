# %%
from glob import glob # I use this package to select files on my local computer

# %%
# I use the command cd <path> to change directory to be in the folder where my microfading files are.

# %%
cd /home/gpatin/Documents/RCE/projects/2024-144_GP_RMA_Japans-prenten/data/interim/MFT
# Out:
# /home/gpatin/Documents/RCE/projects/2024-144_GP_RMA_Japans-prenten/data/interim/MFT

# %%
# Using the glob method, I selected all the files that contains the expression 'BW1' and 'MFT' in the filename.
files = sorted(glob('*BW1*MFT*'))
files
# Out:
# ['2024-144_MF.BWS0024.01_G01_BW1_model_2024-07-30_MFT2.xlsx',
#  '2024-144_MF.BWS0024.02_G01_BW1_model_2024-07-30_MFT2.xlsx',
#  '2024-144_MF.BWS0024.03_G01_BW1_model_2024-07-30_MFT2.xlsx',
#  '2024-144_MF.BWS0024.04_G02_BW1_model_2024-08-02_MFT1.xlsx',
#  '2024-144_MF.BWS0024.05_G02_BW1_model_2024-08-02_MFT1.xlsx',
#  '2024-144_MF.BWS0024.06_G02_BW1_model_2024-08-02_MFT1.xlsx']

# %%
import microfading as mf

# %%
files = mf.get_datasets()
m = mf.MFT(files=files)

# %%
m.plot
